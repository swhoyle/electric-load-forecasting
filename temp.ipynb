# %%
import pandas as pd

df = pd.read_parquet("./data/003_feature_engineered/1min_power_load.parquet")
df.head()
# Out:
#             timestamp         load workday        lag_1        lag_2  \
# 0 2025-11-28 00:00:00  1912.400000    full          NaN          NaN
# 1 2025-11-28 00:01:00  1908.233333    full  1912.400000          NaN
# 2 2025-11-28 00:02:00  1643.183333    full  1908.233333  1912.400000
# 3 2025-11-28 00:03:00  2992.950000    full  1643.183333  1908.233333
# 4 2025-11-28 00:04:00  1106.000000    full  2992.950000  1643.183333
#
#          lag_3   lag_4  lag_5  lag_10  lag_15  ...  slope_30  slope_60  \
# 0          NaN     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 1          NaN     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 2          NaN     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 3  1912.400000     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 4  1908.233333  1912.4    NaN     NaN     NaN  ...       NaN       NaN
#
#    second  minute  hour  time_of_day  day  weekday  is_weekend  month
# ...

# %%
# Out:
#             timestamp         load workday        lag_1        lag_2  \
# 0 2025-11-28 00:00:00  1912.400000    full          NaN          NaN
# 1 2025-11-28 00:01:00  1908.233333    full  1912.400000          NaN
# 2 2025-11-28 00:02:00  1643.183333    full  1908.233333  1912.400000
# 3 2025-11-28 00:03:00  2992.950000    full  1643.183333  1908.233333
# 4 2025-11-28 00:04:00  1106.000000    full  2992.950000  1643.183333
#
#          lag_3   lag_4  lag_5  lag_10  lag_15  ...  slope_30  slope_60  \
# 0          NaN     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 1          NaN     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 2          NaN     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 3  1912.400000     NaN    NaN     NaN     NaN  ...       NaN       NaN
# 4  1908.233333  1912.4    NaN     NaN     NaN  ...       NaN       NaN
#
#    second  minute  hour  time_of_day  day  weekday  is_weekend  month
# ...
